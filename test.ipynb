# %%
print(have nice day)
# Out:
# 'Python 3.12.3' でセルを実行するには、 ipykernel パッケージが必要です。
#
# 'ipykernel' を Python 環境にインストールします。
#
# コマンド: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
